# %% [markdown]
# 資料來源：
#  https://www.kaggle.com/c/home-credit-default-risk/data
#
#  application_train.csv

# %%
# 自行抓取csv檔,並再更名為application_train.csv
# Kaggle的不能直接用wget抓,抓取Cupoy上範例提供
# !wget -c https://ai100-fileentity.cupoy.com/ml100/homework/data/1582795763215/application_train.csv?t=1582796969499 -O application_train.csv
# Out:
# --2020-07-19 02:39:34--  https://ai100-fileentity.cupoy.com/ml100/homework/data/1582795763215/application_train.csv?t=1582796969499
# Resolving ai100-fileentity.cupoy.com (ai100-fileentity.cupoy.com)... 13.35.34.121, 13.35.34.71, 13.35.34.3, ...
# Connecting to ai100-fileentity.cupoy.com (ai100-fileentity.cupoy.com)|13.35.34.121|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 166133370 (158M) [application/octet-stream]
# Saving to: ‘application_train.csv’
#
# application_train.c 100%[===================>] 158.44M   100MB/s    in 1.6s
#
# 2020-07-19 02:39:35 (100 MB/s) - ‘application_train.csv’ saved [166133370/166133370]

# %%
# !ls
# Out:
# application_train.csv  sample_data

# %%
# 處理csv檔
import numpy as np
import pandas
import os

train_csv=pandas.read_csv('./application_train.csv')
train_csv.head()
# Out:
#    SK_ID_CURR  TARGET  ... AMT_REQ_CREDIT_BUREAU_QRT AMT_REQ_CREDIT_BUREAU_YEAR
# 0      100002       1  ...                       0.0                        1.0
# 1      100003       0  ...                       0.0                        0.0
# 2      100004       0  ...                       0.0                        0.0
# 3      100006       0  ...                       NaN                        NaN
# 4      100007       0  ...                       0.0                        0.0
#
# [5 rows x 122 columns]

# %%
# 各欄位的基本統計描述
train_csv.describe()
# Out:
#           SK_ID_CURR  ...  AMT_REQ_CREDIT_BUREAU_YEAR
# count  307511.000000  ...               265992.000000
# mean   278180.518577  ...                    1.899974
# std    102790.175348  ...                    1.869295
# min    100002.000000  ...                    0.000000
# 25%    189145.500000  ...                    0.000000
# 50%    278202.000000  ...                    1.000000
# 75%    367142.500000  ...                    3.000000
# max    456255.000000  ...                   25.000000
#
# [8 rows x 106 columns]

# %%
# 每個欄位type
train_csv.dtypes
# Out:
# SK_ID_CURR                      int64
# TARGET                          int64
# NAME_CONTRACT_TYPE             object
# CODE_GENDER                    object
# FLAG_OWN_CAR                   object
#                                ...
# AMT_REQ_CREDIT_BUREAU_DAY     float64
# AMT_REQ_CREDIT_BUREAU_WEEK    float64
# AMT_REQ_CREDIT_BUREAU_MON     float64
# AMT_REQ_CREDIT_BUREAU_QRT     float64
# AMT_REQ_CREDIT_BUREAU_YEAR    float64
# Length: 122, dtype: object

# %%
# 資料大小
train_csv.shape
# Out:
# (307511, 122)
